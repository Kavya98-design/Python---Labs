# %%
import requests

# %%
import os 
from PIL import Image
from IPython.display import IFrame

# %%
url = 'https://pngtree.com/free-png'
url
# Out:
# 'https://pngtree.com/free-png'

# %%
r = requests.get(url)

# %%
r
# Out:
# <Response [200]>

# %%
print(r.headers)
# Out:
# {'Date': 'Wed, 09 Mar 2022 14:46:00 GMT', 'Content-Type': 'text/html; charset=UTF-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'X-Frame-Options': 'sameorigin', 'Set-Cookie': 'ajax_lang=deleted; expires=Thu, 01-Jan-1970 00:00:01 GMT; Max-Age=0; path=/; domain=.pngtree.com, one_down=a9cf1469fb3373f242e15286aba0a092e41f3e16ecca28de343cd33ecd3dbcd1a%3A2%3A%7Bi%3A0%3Bs%3A8%3A%22one_down%22%3Bi%3A1%3Bi%3A1%3B%7D; expires=Thu, 10-Mar-2022 14:46:00 GMT; Max-Age=86400; path=/; domain=.pngtree.com; secure; HttpOnly, is_old=9ba3416ce0a0c6c7d0c8b8e4bc8b5f8f811bc8fdb2a21f4e509d0df0806192fba%3A2%3A%7Bi%3A0%3Bs%3A6%3A%22is_old%22%3Bi%3A1%3Bi%3A0%3B%7D; expires=Thu, 10-Mar-2022 00:00:00 GMT; Max-Age=33240; path=/; domain=.pngtree.com; secure; HttpOnly, coupon_version=f44e41460fa0bbbafae3e79d078a5b0a2f6db56223da5d095864007437c1fb2fa%3A2%3A%7Bi%3A0%3Bs%3A14%3A%22coupon_version%22%3Bi%3A1%3Bs%3A9%3A%225th-combo%22%3B%7D; expires=Thu, 10-Mar-2022 14:46:00 GMT; Max-Age=86400; path=/; d
# ...

# %%
r.headers['content-type']
# Out:
# 'text/html; charset=UTF-8'

# %%
path = os.path.join(os.getcwd(),"image2.png")
path
# Out:
# 'C:\\Users\\ADMIN\\Desktop\\Just do it\\IBM data analyst - professional certificate\\Study materials\\image2.png'

# %%
with open (path, 'wb') as f:
    f.write(r.content)

# %%
Image.open(path)
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2528/1028834159.py in <module>
# ----> 1 Image.open(path)
#
# ~\anaconda3\lib\site-packages\PIL\Image.py in open(fp, mode, formats)
#    3028     for message in accept_warnings:
#    3029         warnings.warn(message)
# -> 3030     raise UnidentifiedImageError(
#    3031         "cannot identify image file %r" % (filename if filename else fp)
#    3032     )
#
# UnidentifiedImageError: cannot identify image file 'C:\\Users\\ADMIN\\Desktop\\Just do it\\IBM data analyst - professional certificate\\Study materials\\image2.png'

# %%
url = 'https://www.india.com'
url
# Out:
# 'https://www.india.com'

# %%
r = requests.get(url)
r
# Out:
# <Response [200]>

# %%
r.request.headers
# Out:
# {'User-Agent': 'python-requests/2.26.0', 'Accept-Encoding': 'gzip, deflate, br', 'Accept': '*/*', 'Connection': 'keep-alive'}

# %%
header = r.headers
header
# Out:
# {'Content-Type': 'text/html; charset=UTF-8', 'GEO-INFO': 'Akamai set: (GLOBAL)', 'Server': 'IndiaWeb/10.1.10', 'Strict-Transport-Security': 'max-age=31536000; includeSubDomains', 'X-AK-COUNTRY': 'Akamai set: (GLOBAL)', 'X-AK-CountryDetails': 'IN,2409:4072:6d85:8a92:c97f:ed39:4756:3ea9', 'X-BE2': 'india_lb', 'x-content-type-options': 'nosniff', 'X-COUNTRY': 'Akamai set: (1)', 'X-Country-Code': 'US', 'X-CUA': 'Akamai set: ((null))', 'X-Var-ttl': '60.000', 'X-VarCache': 'HIT (2)', 'X-XFF': '2409:4072:6d85:8a92:c97f:ed39:4756:3ea9', 'x-xss-protection': '1; mode=block', 'Vary': 'Accept-Encoding', 'Content-Encoding': 'gzip', 'Expires': 'Wed, 09 Mar 2022 14:43:50 GMT', 'Cache-Control': 'max-age=0, no-cache', 'Pragma': 'no-cache', 'Date': 'Wed, 09 Mar 2022 14:43:50 GMT', 'Content-Length': '35170', 'Connection': 'keep-alive', 'Set-Cookie': 'IPD=1; domain=www.india.com; path=/;, traffic_medium=Direct; path=/'}

# %%
header['date']
# Out:
# 'Wed, 09 Mar 2022 14:43:50 GMT'

# %%
header['content-type']
# Out:
# 'text/html; charset=UTF-8'

# %%
r.text[0:300]
r.text
# Out:
# '<!DOCTYPE html>\n<html lang="en" prefix="og: https://ogp.me/ns# fb: https://ogp.me/ns/fb# article: https://ogp.me/ns/article#">\n<head>\n<link rel="preconnect" href="https://www.india.com">\n<link rel="preconnect" href="https://s3.india.com">\n<link href="//india.com" rel="dns-prefetch"> <link href="//s3.india.com" rel="dns-prefetch"> <link href="//sb.scorecardresearch.com" rel="dns-prefetch"> <link href="//sb.scorecardresearch.com" rel="preconnect">  <link href="//www.googletagservices.com" rel="dns-prefetch"/> <link href="//www.googletagservices.com" rel="preconnect"/><link href="//fonts.gstatic.com" rel="preconnect"> <link href="//stats.g.doubleclick.net" rel="dns-prefetch"> <link href="//stats.g.doubleclick.net" rel="preconnect"> <link href="//cdn.onthe.io" rel="dns-prefetch"> <link href="//cdn.onthe.io" rel="preconnect"> <link href="//www.googletagmanager.com" rel="dns-prefetch"> <link href="//www.googletagmanager.com" rel="preconnect"> <link href="//st1.bollywoodlife.com" rel=
# ...

# %%
import requests
url_get ='https://www.w3.org/TR/PNG/iso_8859-1.txt'
url_get
# Out:
# 'https://www.w3.org/TR/PNG/iso_8859-1.txt'

# %%
Dict = {"name":"Harry", "ID":"4"}
Dict
# Out:
# {'name': 'Harry', 'ID': '4'}

# %%
r=requests.get(url_get, params = Dict)
r
# Out:
# <Response [200]>

# %%
r.url
# Out:
# 'https://www.w3.org/TR/PNG/iso_8859-1.txt?name=Harry&ID=4'

# %%
r.request.body

# %%
r.headers['content-type']
# Out:
# 'text/plain'

# %%
r.text
# Out:
# "The following are the graphical (non-control) characters defined by\nISO 8859-1 (1987).  Descriptions in words aren't all that helpful,\nbut they're the best we can do in text.  A graphics file illustrating\nthe character set should be available from the same archive as this\nfile.\n\nHex Description                 Hex Description\n\n20  SPACE\n21  EXCLAMATION MARK            A1  INVERTED EXCLAMATION MARK\n22  QUOTATION MARK              A2  CENT SIGN\n23  NUMBER SIGN                 A3  POUND SIGN\n24  DOLLAR SIGN                 A4  CURRENCY SIGN\n25  PERCENT SIGN                A5  YEN SIGN\n26  AMPERSAND                   A6  BROKEN BAR\n27  APOSTROPHE                  A7  SECTION SIGN\n28  LEFT PARENTHESIS            A8  DIAERESIS\n29  RIGHT PARENTHESIS           A9  COPYRIGHT SIGN\n2A  ASTERISK                    AA  FEMININE ORDINAL INDICATOR\n2B  PLUS SIGN                   AB  LEFT-POINTING DOUBLE ANGLE QUOTATION MARK\n2C  COMMA                       AC  NOT SIGN\n2D  HYPH
# ...

# %%
url_post = 'http://httpbin.org/get'
Payload = {"city":"Alexandria","Code":"45"}
r_post = requests.post(url_post, data = Payload)
r_post
# Out:
# <Response [405]>

# %%
print(r_post.url)
# Out:
# http://httpbin.org/get

# %%
print(r_post.request.body)
# Out:
# city=Alexandria&Code=45

# %%
url_get = 'http://httpbin.org/get'
Payload = {"city":"Alexandria","Code":"45"}
r = requests.get(url_get, params = Payload)
r
r.url
print(r.url)
r.text
r.headers['content-type']
r.json()
r.json()['args']
# Out:
# http://httpbin.org/get?city=Alexandria&Code=45
# {'Code': '45', 'city': 'Alexandria'}
